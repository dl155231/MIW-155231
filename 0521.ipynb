# %% [markdown]
# SVD - szukanie wartości singularnych
# wartosc singularna - pierwiastek z wartosci wlasnej
# Sigma - lewe wektory własne
# V - prawe wektory własne
# U - baza ortonormalna
# $v_1,...,v_n$ - wektory własne macierzy $A^TA$ (prawostronne) - baza ortonormalna
# $Av_1, ..., Av_r$ - baza ortogonalna dla R
# $AA^T = u_1, ..., u_n$
# $(Av_i)^T(Av_i) = V_i^TA^TAv_i = v_i^T\lambda_iv_i = \lambda_iv_i^Tv_i = \lambda_i*1 = \lambda$
# $\sigma_i = \sqrt{\lambda_i}$ | $ \frac{Av_i}{\sigma_i} = u_i$
# $ Xv = \lambda v$
# $ X = A^TA$
# $\lambda$ - skalar i wartość własna
# $ AV = [Av_1, ..., Av_r, 0, ..., 0] = [\sigma_iu_i, ..., \sigma_ru_r, 0, ..., 0]$
# $U\Sigma = [u_1, ..., u_r, 0, ..., 0] =  [\sigma_iu_i, ..., \sigma_ru_r, 0, ..., 0]$
# $AV = U\Sigma |  V^T$ ($V^T=V^{-1}$)
# $A = U\Sigma V^T$
# $A = AVV^T$
# $A = U\Sigma V^T$
# MxN = MxM * MxN * NxN

# %% [markdown]
# $$\begin{bmatrix}
# 1 & 2 & 0\\
# 2 & 0 & 2\\
# \end{bmatrix}
# $$
#
# $$
# AA^T =
# \begin{bmatrix}
# 1 & 2 & 0\\
# 2 & 0 & 2\\
# \end{bmatrix}
# *
# \begin{bmatrix}
# 1 & 2\\
# 2 & 0\\
# 0 & 2\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# 5 & 2\\
# 2 & 8\\
# \end{bmatrix}
# $$
#
# $$
# \begin{vmatrix}
# 5 - \lambda & 2\\
# 2 & 8- \lambda\\
# \end{vmatrix}
# = (5-\lambda)(8-\lambda) - 4 = \lambda^2 -13\lambda + 36
# $$
# $\delta = b^2 -4ac = 169 - 4*1*36 = 169-144=25$
# $\sqrt{\delta} = 5$
# $\lambda_2 = \frac{13-5}{2} = 4$
# $\lambda_1 = \frac{13+5}{2} = 9$
# $\sigma_2 = 2$
# $\sigma_1 = 3$
# $$
# \begin{bmatrix}
# 5-9 & 2\\
# 2 & 8-9\\
# \end{bmatrix}
# *
# \begin{bmatrix}
# u_1^1\\
# u_1^2\\
# \end{bmatrix}
# = 0
# $$
# $-4u_1^1 + 2 u_1^2 = 0$
# $2u_1^1 - u_1^2 = 0 => u_1^2 = 2u_1^1 => u_1^2 - 2$
# $u_1 = \alpha \begin{bmatrix}1 & 2\end{bmatrix}^T$
# $$\begin{bmatrix}
# 5-4 & 2\\
# 2 & 8-4\\
# \end{bmatrix}
# *
# \begin{bmatrix}
# u_1^1\\
# u_1^2\\
# \end{bmatrix}
# = 0
# $$

# %% [markdown]
# $$\begin{bmatrix}
# 5 - \lambda & 2 & 4\\
# 2 & 4-\lambda & 0\\
# 4 & 0 & 4-\lambda\\
# \end{bmatrix}
# = (5-\lambda)(4-\lambda)(4-\lambda) - 20(4-\lambda) = (4-\lambda)((5-\lambda)(4-\lambda)-20) = 0
# $$
# $4-\lambda = 0$ -> $\lambda = 4$
# $ (5-\lambda)(4-\lambda) - 20 = 0$
# $\lambda^2-9\lambda+20-20 = 0$
# $\lambda^2-9\lambda = 0$
# $\lambda(\lambda-9) = 0$
# $\lambda= 5 \vee \lambda = -9$
# $v_1 = \frac{1}{3\sqrt{5}}\begin{bmatrix} 5 & 2 & 4\\\end{bmatrix}^T$
# $v_2 = \frac{1}{\sqrt{5}}\begin{bmatrix}0&2&-1\end{bmatrix}^T$
# $v_3 = \frac{1}{3}\begin{bmatrix}2&1&2\end{bmatrix}$

# %% [markdown]
# $$
# \begin{bmatrix}
# 1&2&0\\
# 2&0&2\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}\\
# \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}}\\
# \end{bmatrix}
# *
# \begin{bmatrix}
# 3&0&0\\
# 0&2&0\\
# \end{bmatrix}
# $$

# %% [markdown]
# $$A = U\Sigma V^T$$
# $$A^T = (U\Sigma V^T)^T$$
# $$V = A^TU\Sigma^{-1}$$
# $$V^T - wyprostowanie wektorów  $$
# $$v_1 = A^Tu_1 * \frac{1}{\sigma_1}$$
# $$[[v_1]...] = A^T[[u_1]...]
#     \begin{bmatrix}
#     \frac{1}{\sigma_1} & 0 & 0\\
#     0 & \frac{1}{\sigma_1} & 0\\
#     0 & 0 & \frac{1}{\sigma_1}\\
#     \end{bmatrix}
# $$

# %% [markdown]
# $$
# v_1 =
# \begin{bmatrix}
#     1 & 2\\
#     2 & 0\\
#     0 & 2\\
# \end{bmatrix}
# *
# \begin{bmatrix}
#     \frac{1}{\sqrt{5}}\\
#     \frac{2}{\sqrt{5}}\\
#     \end{bmatrix}
# *
# \frac{1}{3}
# =
# \begin{bmatrix}
#     \frac{5}{3\sqrt{5}}\\
#     \frac{2}{3\sqrt{5}}\\
#     \frac{4}{3\sqrt{5}}\\
# \end{bmatrix}
# $$
# $$v_2 =
# \begin{bmatrix}
#     1 & 2\\
#     2 & 0\\
#     0 & 2\\
# \end{bmatrix}
# *
# \begin{bmatrix}
#     \frac{2}{\sqrt{5}}\\
#     \frac{-1}{\sqrt{5}}\\
# \end{bmatrix}
# *
# \frac{1}{2}
# =
# \begin{bmatrix}
#     0\\
#     \frac{2}{\sqrt{5}}\\
#     \frac{-1}{\sqrt{5}}\\
# \end{bmatrix}
# $$
# $$v_3 =
# \begin{bmatrix}
#     5 & 2 & 4\\
#     2 & 4 & 0\\
#     4 & 0 & 4\\
# \end{bmatrix}
# *
# \begin{bmatrix}
#     a_1\\
#     a_2\\
#     a_3\\
# \end{bmatrix}
# =
# 0
# $$
# $5a_1 + 2a_2 + 4a_3 = 0$
# $2a_1 + 4a_2 + 0a_3 = 0$ -> $2a_2 = -a_1$, $a_3 = -a_1$
# $4a_1 + 0a_2 + 4a_3 = 0$
# $$
# \frac{1}{3}
# \begin{bmatrix}
#     2 & -1 & -2
# \end{bmatrix}
# \vee
# \begin{bmatrix}
#     -2 & 1 & 2
# \end{bmatrix}$$

# %% [markdown]
# $$
# \begin{bmatrix}
#     \frac{1}{\sqrt{5}} & \frac{2}{\sqrt{5}}\\
#     \frac{2}{\sqrt{2}} & -\frac{1}{\sqrt{5}}\\
# \end{bmatrix}
# \begin{bmatrix}
#     3 & 0 & 0\\
#     0 & 2 & 0\\
# \end{bmatrix}
# \begin{bmatrix}
# \frac{5}{3\sqrt{5}} & \frac{2}{3\sqrt{5}} & \frac{4}{3\sqrt{5}}\\
# 0 & \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}}\\
# \frac{2}{3} & -\frac{1}{3} & -\frac{2}{3}
# \end{bmatrix}
# $$

# %% [markdown]
# $$
# \begin{bmatrix}
#     \frac{3}{\sqrt{5}} & \frac{4}{\sqrt{5}} & 0\\
#     \frac{6}{\sqrt{2}} & -\frac{2}{\sqrt{5}} & 0\\
# \end{bmatrix}
# \begin{bmatrix}
# \frac{5}{3\sqrt{5}} & \frac{2}{3\sqrt{5}} & \frac{4}{3\sqrt{5}}\\
# 0 & \frac{2}{\sqrt{5}} & -\frac{1}{\sqrt{5}}\\
# \frac{2}{3} & -\frac{1}{3} & -\frac{2}{3}
# \end{bmatrix}
# $$

# %% [markdown]
# $$A^T*\frac{Av}{\sigma}*\frac{1}{\sigma}= \frac{A^TAv}{\sigma^2} = \frac{\lambda v}{\sigma^2} = v$$
